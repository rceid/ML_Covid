# %%
import matplotlib.style as style
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
idx_pre = {'load_1': 285574.2084999911, 'load_10':220364.60919999448, 'load_100': 205775.61479998496, 'load_1k': 167003.92540000007, 'load_bulk': 3585.393599991221}
idx_post =  {'load_1': 242495.85639999853, 'load_10':167821.83949999558, 'load_100': 156042.99809999252, 'load_1k': 163289.8038999925, 'load_bulk': 3698.1688999803737}
idx_never =  {'load_1':273532.0, 'load_10':231742.0, 'load_100':  152374.0, 'load_1k':159805.0, 'load_bulk': 3428.205900010653}
tweet_loading = {'insp load time w/o idx': 3057.942500017816, 'tweet load time w/o idx' :1396766.0, 'insp load time w/ idx': 3026.843800005736, 'tweet load time w/ idx':  1340677.0}

def load_stats(d, title, ylim=300000):
    fig, ax = plt.subplots(figsize=(12, 8))
    ax.set_ylim([0,ylim])
    for k, v in d.items():
        plt.title(label=title)
        g = plt.bar(k,v)
        
load_stats(idx_pre, 'idx_pre')
load_stats(idx_post, 'idx_post')
load_stats(idx_never, 'idx_never')
load_stats(tweet_loading, 'tweet_loading', ylim=1750000)
