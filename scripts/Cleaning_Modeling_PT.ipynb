# %%
## importing all required libraries

# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import datetime as dt
import pipeline

# %%
df = pipeline.create_clean_df()

# %%
df
# Out:
#       Country Code        Date  Recovered  Confirmed  Deaths ADMIN_LEVEL_NAME  \
# 0              AFG  2020-01-22        0.0        0.0     0.0              NaN
# 1              AFG  2020-01-23        0.0        0.0     0.0              NaN
# 2              AFG  2020-01-24        0.0        0.0     0.0              NaN
# 3              AFG  2020-01-25        0.0        0.0     0.0              NaN
# 4              AFG  2020-01-26        0.0        0.0     0.0              NaN
# ...            ...         ...        ...        ...     ...              ...
# 20179          ZWE  2020-05-12        9.0       36.0     4.0              NaN
# 20180          ZWE  2020-05-13       12.0       37.0     4.0              NaN
# 20181          ZWE  2020-05-14       13.0       37.0     4.0              NaN
# 20182          ZWE  2020-05-15       13.0       42.0     4.0              NaN
# 20183          ZWE  2020-05-16       13.0       42.0     4.0              NaN
#
# ...

# %%
df.join(pd.get_dummies(df['CATEGORY'], prefix= "acaps_cat_"))
# Out:
#          Country_x Country Code        Date  Recovered  Confirmed  Deaths  \
# 0      Afghanistan          AFG  2020-01-22        0.0        0.0     0.0
# 1      Afghanistan          AFG  2020-01-23        0.0        0.0     0.0
# 2      Afghanistan          AFG  2020-01-24        0.0        0.0     0.0
# 3      Afghanistan          AFG  2020-01-25        0.0        0.0     0.0
# 4      Afghanistan          AFG  2020-01-26        0.0        0.0     0.0
# ...            ...          ...         ...        ...        ...     ...
# 20179     Zimbabwe          ZWE  2020-05-12        9.0       36.0     4.0
# 20180     Zimbabwe          ZWE  2020-05-13       12.0       37.0     4.0
# 20181     Zimbabwe          ZWE  2020-05-14       13.0       37.0     4.0
# 20182     Zimbabwe          ZWE  2020-05-15       13.0       42.0     4.0
# 20183     Zimbabwe          ZWE  2020-05-16       13.0       42.0     4.0
#
#          Country_y ADMIN_LEVEL_NAME  PCODE REGION  ... Alternative source  \
# ...
