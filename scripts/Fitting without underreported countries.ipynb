# %%
import pipeline
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading data

# %%
filepath = '../data/covid_df.pkl'
df = pd.read_pickle(filepath)

# %%
max(df['Date'])
# Out:
# datetime.date(2020, 5, 29)

# %% [markdown]
# ## Creating log target of confirmed cases

# %%
df['log_cases'] = np.log(df['Confirmed Cases']+1)

# %% [markdown]
# ## Dropping China, Russia and Brazil

# %%
df = df[df['Country'] != 'China']
df = df[df['Country'] != 'Russia']
df = df[df['Country'] != 'Brazil']

# %%
weeks_for_cv = [0,1,2,3,4,5,6]
n_weeks_prediction = 2
results = {}
for i in weeks_for_cv:
    shorter_df = pipeline.cut_df_on_weeks(df, i)
    df_train, df_test = pipeline.split_and_scale_on_last_weeks(shorter_df, n_weeks_prediction)
    pipeline.sanity_check(df_train, df_test)
    X_train, y_train = pipeline.divide_target_and_features(df_train, 'log_cases')
    X_test, y_test = pipeline.divide_target_and_features(df_test, 'log_cases')
    dct = pipeline.train_and_evaluate(X_train, y_train, X_test, y_test)
    results['Until week: ' +str(i)] = dct
# Out:
# Cutting dataframe on date: 2020-05-29
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     2.256314
# 8             EconomicSupportIndex     0.233803
# 19   Days Elapsed Since First Case     0.060904
# 18                       Day Count     0.007023
# 143                  Country_Syria    -0.000000
# 134               Country_Slovenia     0.000000
# 135           Country_South Africa     0.000000
# 136            Country_South Korea     0.000000
# 137                  Country_Spain     0.000000
# 138              Country_Sri Lanka    -0.000000
#
# Bias: 3.02
# Mean squared error: 3.94
# RSS: 5698.12
# Variance score: 0.76
#
# R2 score: 0.40
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     9.644856
# 108                Country_Nepal    -3.123086
# 158              Country_Vietnam    -2.703080
# 104             Country_Mongolia    -2.125637
# 195        E1_Income support_2.0     2.068735
# 193        E1_Income support_0.0    -1.945866
# 144           Country_Tajikistan     1.929056
# 84                 Country_Japan     1.908605
# 78                  Country_Iran     1.851447
# 196  E2_Debt/contract relief_0.0    -1.818072
#
# Bias: 1.19
# Mean squared error: 1.87
# RSS: 2714.73
# Variance score: 0.91
#
# R2 score: 0.71
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                          Feature   Coefficient
# 0                      Intercept  2.350175e+10
# 205       H3_Contact tracing_0.0 -8.375247e+09
# 206       H3_Contact tracing_1.0 -8.375247e+09
# 207       H3_Contact tracing_2.0 -8.375247e+09
# 196  E2_Debt/contract relief_0.0 -8.306337e+09
# 197  E2_Debt/contract relief_1.0 -8.306337e+09
# 198  E2_Debt/contract relief_2.0 -8.306337e+09
# 170  C3_Cancel public events_0.0 -8.064108e+09
# 171  C3_Cancel public events_1.0 -8.064108e+09
# 172  C3_Cancel public events_2.0 -8.064108e+09
#
# Bias: 1.19
# Mean squared error: 1.86
# RSS: 2695.42
# Variance score: 0.91
#
# R2 score: 0.72
#
# Cutting dataframe on date: 2020-05-22
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     2.165672
# 8             EconomicSupportIndex     0.280488
# 19   Days Elapsed Since First Case     0.059064
# 18                       Day Count     0.008411
# 144            Country_Switzerland     0.000000
# 135        Country_Slovak Republic     0.000000
# 136               Country_Slovenia     0.000000
# 137           Country_South Africa     0.000000
# 138            Country_South Korea     0.000000
# 139                  Country_Spain     0.000000
#
# Bias: 2.91
# Mean squared error: 3.96
# RSS: 7622.86
# Variance score: 0.75
#
# R2 score: 0.40
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     8.157308
# 80                  Country_Iran     2.138783
# 110                Country_Nepal    -2.079578
# 197        E1_Income support_2.0     2.077867
# 195        E1_Income support_0.0    -1.927446
# 198  E2_Debt/contract relief_0.0    -1.776468
# 30               Country_Belarus     1.616950
# 106             Country_Mongolia    -1.588009
# 200  E2_Debt/contract relief_2.0     1.478184
# 160              Country_Vietnam    -1.390901
#
# Bias: 1.15
# Mean squared error: 2.05
# RSS: 3944.01
# Variance score: 0.90
#
# R2 score: 0.69
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                          Feature   Coefficient
# 137         Country_South Africa -6.184048e+09
# 174  C3_Cancel public events_2.0  6.166621e+09
# 173  C3_Cancel public events_1.0  6.166621e+09
# 172  C3_Cancel public events_0.0  6.166621e+09
# 98            Country_Madagascar  6.162685e+09
# 200  E2_Debt/contract relief_2.0  5.853739e+09
# 199  E2_Debt/contract relief_1.0  5.853739e+09
# 198  E2_Debt/contract relief_0.0  5.853739e+09
# 13               Life Expectancy -4.926760e+09
# 82               Country_Ireland  4.518628e+09
#
# Bias: 1.15
# Mean squared error: 2.04
# RSS: 3932.61
# Variance score: 0.90
#
# R2 score: 0.69
#
# Cutting dataframe on date: 2020-05-15
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     2.076679
# 8             EconomicSupportIndex     0.329880
# 19   Days Elapsed Since First Case     0.056831
# 18                       Day Count     0.009460
# 144            Country_Switzerland     0.000000
# 135        Country_Slovak Republic     0.000000
# 136               Country_Slovenia     0.000000
# 137           Country_South Africa     0.000000
# 138            Country_South Korea     0.000000
# 139                  Country_Spain     0.000000
#
# Bias: 2.79
# Mean squared error: 3.94
# RSS: 7810.85
# Variance score: 0.74
#
# R2 score: 0.42
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     8.350167
# 80                  Country_Iran     2.143747
# 197        E1_Income support_2.0     2.114539
# 110                Country_Nepal    -1.979072
# 195        E1_Income support_0.0    -1.912784
# 198  E2_Debt/contract relief_0.0    -1.757927
# 106             Country_Mongolia    -1.590056
# 30               Country_Belarus     1.512461
# 200  E2_Debt/contract relief_2.0     1.470923
# 160              Country_Vietnam    -1.311120
#
# Bias: 1.11
# Mean squared error: 2.21
# RSS: 4377.99
# Variance score: 0.90
#
# R2 score: 0.68
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                                Feature   Coefficient
# 172        C3_Cancel public events_0.0 -2.689077e+10
# 173        C3_Cancel public events_1.0 -2.689077e+10
# 174        C3_Cancel public events_2.0 -2.689077e+10
# 176  C4_Restrictions on gatherings_1.0  1.811304e+10
# 177  C4_Restrictions on gatherings_2.0  1.811304e+10
# 179  C4_Restrictions on gatherings_4.0  1.811304e+10
# 175  C4_Restrictions on gatherings_0.0  1.811304e+10
# 178  C4_Restrictions on gatherings_3.0  1.811304e+10
# 110                      Country_Nepal  1.634987e+10
# 0                            Intercept  1.588513e+10
#
# Bias: 1.11
# Mean squared error: 2.21
# RSS: 4385.77
# Variance score: 0.90
#
# R2 score: 0.68
#
# Cutting dataframe on date: 2020-05-08
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     1.975383
# 8             EconomicSupportIndex     0.368679
# 19   Days Elapsed Since First Case     0.054144
# 18                       Day Count     0.010265
# 144            Country_Switzerland     0.000000
# 135        Country_Slovak Republic    -0.000000
# 136               Country_Slovenia     0.000000
# 137           Country_South Africa     0.000000
# 138            Country_South Korea     0.000000
# 139                  Country_Spain     0.000000
#
# Bias: 2.66
# Mean squared error: 3.99
# RSS: 7859.73
# Variance score: 0.73
#
# R2 score: 0.44
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     8.416150
# 80                  Country_Iran     2.111643
# 197        E1_Income support_2.0     2.104305
# 110                Country_Nepal    -1.844302
# 195        E1_Income support_0.0    -1.838763
# 198  E2_Debt/contract relief_0.0    -1.720139
# 106             Country_Mongolia    -1.623402
# 200  E2_Debt/contract relief_2.0     1.445261
# 30               Country_Belarus     1.396533
# 160              Country_Vietnam    -1.190520
#
# Bias: 1.05
# Mean squared error: 2.31
# RSS: 4552.29
# Variance score: 0.89
#
# R2 score: 0.68
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                               Feature   Coefficient
# 137              Country_South Africa  8.438242e+08
# 98                 Country_Madagascar -8.098762e+08
# 0                           Intercept -7.693987e+08
# 63                   Country_Eswatini  7.552231e+08
# 13                    Life Expectancy  6.590389e+08
# 115                   Country_Nigeria  6.165055e+08
# 94                    Country_Lesotho  5.832973e+08
# 28                 Country_Bangladesh -5.746944e+08
# 21                    Country_Albania -5.705071e+08
# 44   Country_Central African Republic  5.652015e+08
#
# Bias: 1.05
# Mean squared error: 2.30
# RSS: 4540.72
# Variance score: 0.89
#
# R2 score: 0.68
#
# Cutting dataframe on date: 2020-05-01
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     1.879901
# 8             EconomicSupportIndex     0.384218
# 19   Days Elapsed Since First Case     0.051280
# 18                       Day Count     0.010348
# 144                  Country_Syria    -0.000000
# 135               Country_Slovenia     0.000000
# 136           Country_South Africa     0.000000
# 137            Country_South Korea     0.000000
# 138                  Country_Spain     0.000000
# 139              Country_Sri Lanka    -0.000000
#
# Bias: 2.52
# Mean squared error: 4.16
# RSS: 8253.92
# Variance score: 0.71
#
# R2 score: 0.43
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     8.656572
# 196        E1_Income support_2.0     2.210298
# 79                  Country_Iran     1.961990
# 194        E1_Income support_0.0    -1.880204
# 109                Country_Nepal    -1.826380
# 197  E2_Debt/contract relief_0.0    -1.810818
# 30               Country_Belarus     1.770467
# 199  E2_Debt/contract relief_2.0     1.574017
# 105             Country_Mongolia    -1.521306
# 85                 Country_Japan     1.270921
#
# Bias: 0.99
# Mean squared error: 2.40
# RSS: 4757.71
# Variance score: 0.88
#
# R2 score: 0.67
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                                       Feature   Coefficient
# 0                                   Intercept  3.845231e+10
# 155          Country_United States of America  3.298468e+10
# 186  C7_Restrictions on internal movement_0.0 -2.313750e+10
# 188  C7_Restrictions on internal movement_2.0 -2.313750e+10
# 187  C7_Restrictions on internal movement_1.0 -2.313750e+10
# 167                  C2_Workplace closing_0.0 -2.135943e+10
# 168                  C2_Workplace closing_1.0 -2.135943e+10
# 169                  C2_Workplace closing_2.0 -2.135943e+10
# 170                  C2_Workplace closing_3.0 -2.135943e+10
# 207                    H3_Contact tracing_0.0 -1.813684e+10
#
# Bias: 0.99
# Mean squared error: 2.39
# RSS: 4727.67
# Variance score: 0.89
#
# R2 score: 0.67
#
# Cutting dataframe on date: 2020-04-24
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     1.918715
# 8             EconomicSupportIndex     0.332667
# 5                  StringencyIndex     0.128386
# 19   Days Elapsed Since First Case     0.047888
# 18                       Day Count     0.006880
# 145                  Country_Syria    -0.000000
# 136               Country_Slovenia     0.000000
# 137           Country_South Africa     0.000000
# 138            Country_South Korea     0.000000
# 139                  Country_Spain     0.000000
#
# Bias: 2.26
# Mean squared error: 4.71
# RSS: 9386.51
# Variance score: 0.69
#
# R2 score: 0.36
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     8.688013
# 197        E1_Income support_2.0     2.273780
# 198  E2_Debt/contract relief_0.0    -1.882474
# 195        E1_Income support_0.0    -1.873713
# 80                  Country_Iran     1.853104
# 200  E2_Debt/contract relief_2.0     1.703804
# 30               Country_Belarus     1.680282
# 110                Country_Nepal    -1.619647
# 106             Country_Mongolia    -1.514785
# 86                 Country_Japan     1.413317
#
# Bias: 0.91
# Mean squared error: 2.48
# RSS: 4944.50
# Variance score: 0.87
#
# R2 score: 0.66
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                                  Feature   Coefficient
# 156     Country_United States of America -3.312857e+10
# 0                              Intercept -1.141294e+10
# 86                         Country_Japan -9.666242e+09
# 201  H1_Public information campaigns_0.0 -8.835131e+09
# 202  H1_Public information campaigns_1.0 -8.835131e+09
# 203  H1_Public information campaigns_2.0 -8.835131e+09
# 200          E2_Debt/contract relief_2.0  7.556560e+09
# 199          E2_Debt/contract relief_1.0  7.556560e+09
# 198          E2_Debt/contract relief_0.0  7.556560e+09
# 71                       Country_Germany -6.853506e+09
#
# Bias: 0.91
# Mean squared error: 2.47
# RSS: 4936.35
# Variance score: 0.87
#
# R2 score: 0.66
#
# Cutting dataframe on date: 2020-04-17
# Success: Features match
# Success: No NAs remain
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     1.899073
# 6          GovernmentResponseIndex     0.250652
# 8             EconomicSupportIndex     0.207848
# 19   Days Elapsed Since First Case     0.043607
# 18                       Day Count     0.003001
# 146                  Country_Syria    -0.000000
# 136        Country_Slovak Republic    -0.000000
# 137               Country_Slovenia     0.000000
# 138           Country_South Africa     0.000000
# 139            Country_South Korea     0.000000
#
# Bias: 1.98
# Mean squared error: 5.73
# RSS: 11507.62
# Variance score: 0.65
#
# R2 score: 0.22
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     8.924142
# 198        E1_Income support_2.0     2.432766
# 199  E2_Debt/contract relief_0.0    -2.048498
# 196        E1_Income support_0.0    -1.949773
# 201  E2_Debt/contract relief_2.0     1.913210
# 81                  Country_Iran     1.846153
# 107             Country_Mongolia    -1.660657
# 111                Country_Nepal    -1.237620
# 149             Country_Thailand     1.183726
# 166        C1_School closing_1.0     1.145026
#
# Bias: 0.82
# Mean squared error: 2.59
# RSS: 5190.23
# Variance score: 0.86
#
# R2 score: 0.65
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                                       Feature   Coefficient
# 0                                   Intercept  8.090071e+10
# 169                  C2_Workplace closing_0.0 -2.777887e+10
# 170                  C2_Workplace closing_1.0 -2.777887e+10
# 171                  C2_Workplace closing_2.0 -2.777887e+10
# 172                  C2_Workplace closing_3.0 -2.777887e+10
# 188  C7_Restrictions on internal movement_0.0 -2.643620e+10
# 190  C7_Restrictions on internal movement_2.0 -2.643620e+10
# 189  C7_Restrictions on internal movement_1.0 -2.643620e+10
# 184          C6_Stay at home requirements_0.0 -2.246199e+10
# 185          C6_Stay at home requirements_1.0 -2.246199e+10
#
# Bias: 0.82
# Mean squared error: 2.59
# RSS: 5192.49
# Variance score: 0.86
#
# R2 score: 0.65

# %% [markdown]
# ## Predicting with best model

# %%
from sklearn import linear_model
n_weeks_prediction = 2
df_train, df_test = pipeline.split_and_scale_on_last_weeks(df, n_weeks_prediction)
X_train, y_train = pipeline.divide_target_and_features(df_train, 'log_cases')
X_test, y_test = pipeline.divide_target_and_features(df_test, 'log_cases')
lreg = linear_model.LinearRegression()
lreg.fit(X_train, y_train)
y_pred = lreg.predict(X_test)

# %%
dct = pipeline.train_and_evaluate(X_train, y_train, X_test, y_test)
# Out:
# Lasso: Features with highest magnitude                                coefficients in absolute value
#                            Feature  Coefficient
# 0                        Intercept     2.256314
# 8             EconomicSupportIndex     0.233803
# 19   Days Elapsed Since First Case     0.060904
# 18                       Day Count     0.007023
# 143                  Country_Syria    -0.000000
# 134               Country_Slovenia     0.000000
# 135           Country_South Africa     0.000000
# 136            Country_South Korea     0.000000
# 137                  Country_Spain     0.000000
# 138              Country_Sri Lanka    -0.000000
#
# Bias: 3.02
# Mean squared error: 3.94
# RSS: 5698.12
# Variance score: 0.76
#
# R2 score: 0.40
#
# Ridge: Features with highest magnitude                                coefficients in absolute value
#                          Feature  Coefficient
# 0                      Intercept     9.644856
# 108                Country_Nepal    -3.123086
# 158              Country_Vietnam    -2.703080
# 104             Country_Mongolia    -2.125637
# 195        E1_Income support_2.0     2.068735
# 193        E1_Income support_0.0    -1.945866
# 144           Country_Tajikistan     1.929056
# 84                 Country_Japan     1.908605
# 78                  Country_Iran     1.851447
# 196  E2_Debt/contract relief_0.0    -1.818072
#
# Bias: 1.19
# Mean squared error: 1.87
# RSS: 2714.73
# Variance score: 0.91
#
# R2 score: 0.71
#
# Linear Regression: Features with highest magnitude                                coefficients in absolute value
#                          Feature   Coefficient
# 0                      Intercept  2.350175e+10
# 205       H3_Contact tracing_0.0 -8.375247e+09
# 206       H3_Contact tracing_1.0 -8.375247e+09
# 207       H3_Contact tracing_2.0 -8.375247e+09
# 196  E2_Debt/contract relief_0.0 -8.306337e+09
# 197  E2_Debt/contract relief_1.0 -8.306337e+09
# 198  E2_Debt/contract relief_2.0 -8.306337e+09
# 170  C3_Cancel public events_0.0 -8.064108e+09
# 171  C3_Cancel public events_1.0 -8.064108e+09
# 172  C3_Cancel public events_2.0 -8.064108e+09
#
# Bias: 1.19
# Mean squared error: 1.86
# RSS: 2695.42
# Variance score: 0.91
#
# R2 score: 0.72

# %%
predictions = pipeline.predictions_every_country(X_test.columns[19:161], X_test, y_pred, y_test)

# %%
predictions
# Out:
#             Afghanistan real  Afghanistan prediction  Albania real  \
# date
# 2020-05-16          8.764522                6.604923      6.839476
# 2020-05-17          8.804625                6.629032      6.853299
# 2020-05-18          8.864040                6.653149      6.855409
# 2020-05-19          8.942984                6.677265      6.856462
# 2020-05-20          9.005282                6.701374      6.872128
# 2020-05-21          9.068431                6.725491      6.877296
# 2020-05-22               NaN                     NaN      6.889591
# 2020-05-23               NaN                     NaN      6.897705
# 2020-05-24               NaN                     NaN      6.906755
# 2020-05-25               NaN                     NaN      6.912743
# 2020-05-26               NaN                     NaN           NaN
# 2020-05-27               NaN                     NaN           NaN
# 2020-05-28               NaN                     NaN           NaN
# 2020-05-29               NaN                     NaN           NaN
#
#             Albania prediction  Algeria real  Algeria prediction  Angola real  \
# date
# 2020-05-16            8.412216      8.827908            8.863518     3.891820
# 2020-05-17            8.436329      8.856518            8.887634     3.891820
# 2020-05-18            8.722225      8.882114            8.911747     3.931826
# 2020-05-19            8.746338      8.906258            8.935860     3.970292
# 2020-05-20            8.770451      8.928375            8.959976     3.970292
# 2020-05-21            8.794563      8.952735            8.984089     4.077537
# 2020-05-22            8.818680      8.977020            9.008202     4.110874
# 2020-05-23            8.842793      9.001346            9.032314     4.127134
# 2020-05-24            8.866905      9.024854            9.056431     4.248495
# 2020-05-25            8.891022           NaN                 NaN     4.262680
# 2020-05-26                 NaN           NaN                 NaN          NaN
# 2020-05-27                 NaN           NaN                 NaN          NaN
# 2020-05-28                 NaN           NaN                 NaN          NaN
# 2020-05-29                 NaN           NaN                 NaN          NaN
#
#             Angola prediction  Argentina real  Argentina prediction  ...  \
# date                                                                 ...
# 2020-05-16           5.654449        8.962648              7.757488  ...
# 2020-05-17           5.623665        8.995785              7.781597  ...
# 2020-05-18           5.647781        9.032648              7.805714  ...
# 2020-05-19           5.671898        9.083643              7.829830  ...
# 2020-05-20           5.696007        9.136048              7.853939  ...
# 2020-05-21           5.720123        9.203517              7.878056  ...
# 2020-05-22           5.744236        9.273315              7.902172  ...
# 2020-05-23           5.768349        9.337325              7.926281  ...
# 2020-05-24           5.792465        9.399058              7.950397  ...
# 2020-05-25           5.816578        9.443751              7.974514  ...
# 2020-05-26                NaN        9.490167              7.998623  ...
# 2020-05-27                NaN        9.542087              8.022739  ...
# 2020-05-28                NaN        9.595807              8.046848  ...
# 2020-05-29                NaN             NaN                   NaN  ...
#
#             Venezuela real  Venezuela prediction  Vietnam real  \
# date
# 2020-05-16        6.224558              7.076756      5.765191
# 2020-05-17             NaN                   NaN      5.771441
# 2020-05-18             NaN                   NaN      5.783825
# 2020-05-19             NaN                   NaN      5.783825
# 2020-05-20             NaN                   NaN      5.783825
# 2020-05-21             NaN                   NaN      5.783825
# 2020-05-22             NaN                   NaN      5.783825
# 2020-05-23             NaN                   NaN      5.786897
# 2020-05-24             NaN                   NaN      5.786897
# 2020-05-25             NaN                   NaN           NaN
# 2020-05-26             NaN                   NaN           NaN
# 2020-05-27             NaN                   NaN           NaN
# 2020-05-28             NaN                   NaN           NaN
# 2020-05-29             NaN                   NaN           NaN
#
#             Vietnam prediction  Yemen real  Yemen prediction  Zambia real  \
# date
# 2020-05-16            6.051254    4.812184          3.283306     6.522093
# 2020-05-17            6.075363    4.859812          3.307423     6.625392
# 2020-05-18            6.099480    4.875197          3.331539     6.635947
# 2020-05-19            6.123596    5.123964          3.355648     6.650279
# 2020-05-20            6.147705    5.220356          3.379765     6.725034
# 2020-05-21            6.171822    5.288267          3.403881     6.765039
# 2020-05-22            6.195934    5.347108          3.427990     6.825460
# 2020-05-23            6.220047    5.361292          3.452106     6.825460
# 2020-05-24            6.244164    5.407172          3.476215     6.825460
# 2020-05-25                 NaN    5.455321          3.500332     6.825460
# 2020-05-26                 NaN    5.521461          3.524448     6.825460
# 2020-05-27                 NaN    5.549076          3.548557     6.964136
# 2020-05-28                 NaN    5.631212          3.572674     6.964136
# 2020-05-29                 NaN    5.648974          3.596790          NaN
#
#             Zambia prediction  Zimbabwe real  Zimbabwe prediction
# date
# 2020-05-16           4.756992       3.761200             5.271351
# 2020-05-17           4.781109       3.806662             5.295460
# 2020-05-18           4.805218       3.850148             5.319576
# 2020-05-19           4.829334       3.850148             5.343693
# 2020-05-20           4.853451       3.891820             5.367802
# 2020-05-21           4.877560       3.951244             5.391918
# 2020-05-22           4.901676       3.951244             5.416035
# 2020-05-23           4.925785       4.043051             5.440144
# 2020-05-24           4.949902       4.043051             5.464260
# 2020-05-25           4.974018       4.043051             5.488369
# 2020-05-26           4.998127       4.043051             5.512486
# 2020-05-27           5.022243       4.890349             5.536602
# 2020-05-28           5.046360       5.010635             5.560711
# 2020-05-29                NaN            NaN                  NaN
#
# [14 rows x 284 columns]

# %%
predictions.to_pickle("../data/predictions_noChinaRussiaBrazil.pkl")
