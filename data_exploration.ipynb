# %% [markdown]
# # Visualizations
# Some plots and data exploration

# %%
import util_reading
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
df_policy = util_reading.main()
df_jhu = util_reading.read_jhu_data(util_reading.jhu_data_url)

# %%
sns.pairplot(df_policy)
